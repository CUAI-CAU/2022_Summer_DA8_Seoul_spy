# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('C:/Users/jimin.DESKTOP-8V20QSQ/Desktop/한남동y.xlsx')
df = data[['인허가일자', '폐업일자']]
df.head()
# Out:
#         인허가일자        폐업일자
# 0  2016-02-16  2017-06-05
# 1  2018-08-03  2019-04-03
# 2  2018-09-28  2019-10-16
# 3  2018-08-03  2019-04-03
# 4  2019-10-16  2021-10-15

# %%
df['인허가일자'] = df['인허가일자'].astype('str')
# Out:
# C:\Users\jimin.DESKTOP-8V20QSQ\AppData\Local\Temp\ipykernel_8592\3863078462.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['인허가일자'] = df['인허가일자'].astype('str')

# %%
df['폐업일자'] = df['폐업일자'].astype('str')
# Out:
# C:\Users\jimin.DESKTOP-8V20QSQ\AppData\Local\Temp\ipykernel_8592\2019294484.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['폐업일자'] = df['폐업일자'].astype('str')

# %%
pd.to_datetime(df['인허가일자'])
# Out:
# 0      2016-02-16
# 1      2018-08-03
# 2      2018-09-28
# 3      2018-08-03
# 4      2019-10-16
#           ...
# 1126   2019-03-21
# 1127   2019-03-20
# 1128   2019-03-27
# 1129   2019-03-29
# 1130   2019-03-29
# Name: 인허가일자, Length: 1131, dtype: datetime64[ns]

# %%
pd.to_datetime(df['폐업일자'])
# Out:
# 0      2017-06-05
# 1      2019-04-03
# 2      2019-10-16
# 3      2019-04-03
# 4      2021-10-15
#           ...
# 1126          NaT
# 1127          NaT
# 1128          NaT
# 1129          NaT
# 1130          NaT
# Name: 폐업일자, Length: 1131, dtype: datetime64[ns]

# %%
df['개업년도'] = ''
df['폐업년도'] = ''
# Out:
# C:\Users\jimin.DESKTOP-8V20QSQ\AppData\Local\Temp\ipykernel_8592\706142522.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['개업년도'] = ''
# C:\Users\jimin.DESKTOP-8V20QSQ\AppData\Local\Temp\ipykernel_8592\706142522.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['폐업년도'] = ''

# %%
for i in range(len(data)) :
    if int(df['인허가일자'][i][:4]) < 2011 :
        df['개업년도'][i] = '2011'
    else :
        df['개업년도'][i] = df['인허가일자'][i][:4]
    if df['폐업일자'][i] == 'NaT' or int(df['폐업일자'][i][:4]) > 2019 :
        df['폐업년도'][i] = '2019'
    else :
        df['폐업년도'][i] = df['폐업일자'][i][:4]
# Out:
# C:\Users\jimin.DESKTOP-8V20QSQ\AppData\Local\Temp\ipykernel_8592\1824988031.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['개업년도'][i] = df['인허가일자'][i][:4]
# C:\Users\jimin.DESKTOP-8V20QSQ\AppData\Local\Temp\ipykernel_8592\1824988031.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['폐업년도'][i] = df['폐업일자'][i][:4]
# C:\Users\jimin.DESKTOP-8V20QSQ\AppData\Local\Temp\ipykernel_8592\1824988031.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
num = pd.read_excel('C:/Users/jimin.DESKTOP-8V20QSQ/Desktop/데이터.xlsx')
num
# Out:
#             숙박및음식점           2011           2012           2013  \
# 0        용산구(사업체수)   14584.000000   15266.000000   15908.000000
# 1        강남구(종업원수)   54668.000000   54416.000000   56463.000000
# 2        용산구(사업체수)    3514.000000    3658.000000    3743.000000
# 3        강남구(종업원수)   10029.000000   10562.000000   10498.000000
# 4   용산구(사업체수/종업원수)       4.150256       4.173319       4.250067
# 5   강남구(사업체수/종업원수)       5.450992       5.152055       5.378453
# 6              종로구    6104.000000    6217.000000    6286.000000
# 7              성동구    3148.000000    3219.000000    3311.000000
# 8              마포구    5948.000000    6366.000000    6612.000000
# 9             영등포구    6600.000000    6751.000000    6841.000000
# 10             종로구   23555.000000   24143.000000   24673.000000
# 11             성동구    8717.000000    9333.000000    9734.000000
# 12             마포구   19432.000000   22179.000000   23362.000000
# 13            영등포구   22751.000000   23443.000000   24120.000000
# ...

# %%
num = num.loc[22:23, :]
num
# Out:
#    숙박및음식점      2011      2012      2013      2014      2015      2016  \
# 22    용산구  3.707195  3.606786  3.803681  3.845618  3.971740  3.835144
# 23    강남구  7.844739  7.343453  7.906377  7.507929  8.169151  7.843316
#
#         2017      2018     2019
# 22  3.789749  4.289873  4.67641
# 23  7.744124  8.191771  8.77605

# %%
num.reset_index(inplace=True)

# %%
num.drop(['index'], axis=1, inplace=True)
# Out:
# C:\Users\jimin.DESKTOP-8V20QSQ\AppData\Local\Temp\ipykernel_8592\2013444360.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num.drop(['index'], axis=1, inplace=True)

# %%
num
# Out:
#   숙박및음식점      2011      2012      2013      2014      2015      2016  \
# 0    용산구  3.707195  3.606786  3.803681  3.845618  3.971740  3.835144
# 1    강남구  7.844739  7.343453  7.906377  7.507929  8.169151  7.843316
#
#        2017      2018     2019
# 0  3.789749  4.289873  4.67641
# 1  7.744124  8.191771  8.77605

# %%
df['성장률'] = 0
# Out:
# C:\Users\jimin.DESKTOP-8V20QSQ\AppData\Local\Temp\ipykernel_8592\2227699619.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['성장률'] = 0

# %%
for i in range(len(df)) :
    if df['개업년도'][i] > df['폐업년도'][i] :
        df['성장률'][i] = ''
    else :
        if int(df['개업년도'][i]) >= 2011 and int(df['폐업년도'][i]) <= 2019 : 
            start = num.loc[0, int(df['개업년도'][i])]
            close = num.loc[0, int(df['폐업년도'][i])]
            print(start, close)
            df['성장률'][i] = (close-start)/start*100
        else :
            df['성장률'][i] = ''
# Out:
# 3.8351444473893452 3.7897492422154864
# 4.289873068432671 4.676410406313943
# 4.289873068432671 4.676410406313943
# 4.289873068432671 4.676410406313943
# C:\Users\jimin.DESKTOP-8V20QSQ\AppData\Local\Temp\ipykernel_8592\1544563194.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['성장률'][i] = (close-start)/start*100
# 4.676410406313943 4.676410406313943
# 3.7071953781512605 3.7897492422154864
# 3.7071953781512605 3.7071953781512605
# 3.7071953781512605 3.606786171574904
# 3.7071953781512605 4.289873068432671
# 3.7071953781512605 3.8456181842070687
# 4.289873068432671 4.676410406313943
# 3.7897492422154864 4.676410406313943
# 3.7897492422154864 4.289873068432671
# 3.7897492422154864 4.289873068432671
# 3.7897492422154864 4.676410406313943
# 3.803680981595092 4.676410406313943
# ...

# %%
data['retail_성장률'] = df['성장률']

# %%
df
# Out:
#            인허가일자        폐업일자  개업년도  폐업년도       성장률
# 0     2016-02-16  2017-06-05  2016  2017 -1.183664
# 1     2018-08-03  2019-04-03  2018  2019  9.010461
# 2     2018-09-28  2019-10-16  2018  2019  9.010461
# 3     2018-08-03  2019-04-03  2018  2019  9.010461
# 4     2019-10-16  2021-10-15  2019  2019  0.000000
# ...          ...         ...   ...   ...       ...
# 1126  2019-03-21         NaT  2019  2019  0.000000
# 1127  2019-03-20         NaT  2019  2019  0.000000
# 1128  2019-03-27         NaT  2019  2019  0.000000
# 1129  2019-03-29         NaT  2019  2019  0.000000
# 1130  2019-03-29         NaT  2019  2019  0.000000
#
# [1131 rows x 5 columns]

# %%
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0       인허가일자 영업상태명        폐업일자  영업일    동  \
# 0             0         308  2016-02-16    폐업  2017-06-05  475  한남동
# 1             1           6  2018-08-03    폐업  2019-04-03  243  한남동
# 2             2          13  2018-09-28    폐업  2019-10-16  383  한남동
# 3             3          22  2018-08-03    폐업  2019-04-03  243  한남동
# 4             4          75  2019-10-16    폐업  2021-10-15   76  한남동
#
#                                       도로명전체주소 업태구분명  \
# 0             서울특별시 용산구 우사단로10길 135, 1층 (한남동)    기타
# 1     서울특별시 용산구 독서당로 46, 지1층 1호 (한남동, 한남아이파크)    기타
# 2  서울특별시 용산구 독서당로 46, 2층 212-2호 (한남동, 한남아이파크)   경양식
# 3     서울특별시 용산구 독서당로 46, 지1층 2호 (한남동, 한남아이파크)    기타
# 4  서울특별시 용산구 독서당로 46, 2층 212-2호 (한남동, 한남아이파크)    기타
#
#    distance to intersection(m)  land use type  가장 가까운 버스장류장까지 거리  \
# 0                   372.780741              1         111.102312
# 1                   128.443225              2         112.709155
# ...

# %%
data.to_excel('C:/Users/jimin.DESKTOP-8V20QSQ/Desktop/한남동y.xlsx')
